# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# default plots in pandas
# <br>note: plot function in pandas actually uses matplotlib and scipy,
# <br>because of that, the environment also have to have matplotlib and scipy installed

# %%
data = pd.Series(np.random.standard_normal(int(1e5)))

# %%
data.hist(bins=100)
# Out:
# <Axes: >

# %%
data.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# seaborn

# %%
sns.histplot(data, bins=100, color='b')
# Out:
# <Axes: ylabel='Count'>
