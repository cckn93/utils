# %% [markdown]
# assume stock price movement is normal distributed

# %%
import numpy as np
import pandas as pd
import matplotlib

# %%
data = pd.DataFrame(np.random.normal(size=500))

# %%
data.plot()
# Out:
# <Axes: >

# %%
data.describe()
# Out:
#                 0
# count  500.000000
# mean    -0.017580
# std      0.960482
# min     -3.648816
# 25%     -0.628668
# 50%      0.046935
# 75%      0.602542
# max      2.576837
